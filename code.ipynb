# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %%
cities
# Out:
# ['vizinga',
#  'mataura',
#  'cherskiy',
#  'barrow',
#  'atuona',
#  'lebu',
#  'georgetown',
#  'nguiu',
#  'urumqi',
#  'henties bay',
#  'luderitz',
#  'hay river',
#  'kodiak',
#  'ushuaia',
#  'mahebourg',
#  'tiksi',
#  'saint-philippe',
#  'winkler',
#  'severo-kurilsk',
#  'kinablangan',
#  'kahului',
#  'tsihombe',
#  'taolanaro',
#  'albany',
#  'torbay',
#  'karratha',
#  'kaitangata',
#  'kapaa',
#  'thompson',
#  'saint-paul',
#  'fairbanks',
#  'evensk',
#  'vaini',
#  'karakendzha',
#  'chuy',
#  'castro',
#  'mar del plata',
#  'hermanus',
#  'cockburn town',
#  'zheleznodorozhnyy',
#  'harper',
#  'puerto carreno',
#  'port alfred',
#  'waipawa',
#  'busselton',
#  'namatanai',
#  'san cristobal',
#  'butaritari',
#  'cidreira',
#  'beloha',
#  'zaragoza',
#  'am timan',
#  'guerrero negro',
#  'ostrovnoy',
#  'maple creek',
#  'norman wells',
#  'new norfolk',
#  'artyom',
#  'santo anastacio',
#  'souillac',
#  'dinghai',
#  'lingao',
#  'hami',
#  'illoqqortoormiut',
#  'hithadhoo',
#  'attawapiskat',
#  'santiago',
#  'numan',
#  'alice springs',
#  'pouembout',
#  'piacabucu',
#  'schweinfurt',
#  'palabuhanratu',
#  'qaanaaq',
#  'sept-iles',
#  'ovsyanka',
#  'bentiu',
#  'hilo',
#  'tura',
#  'east london',
#  'northam',
#  'tasiilaq',
#  'cape town',
#  'faya',
#  'bluff',
#  'fare',
#  'fort nelson',
#  'tuktoyaktuk',
#  'rikitea',
#  'fez',
#  'kushiro',
#  'hasaki',
#  'avarua',
#  'ancud',
#  'belyy yar',
#  'namibe',
#  'russell',
#  'aksay',
#  'alta floresta',
#  'tommot',
#  'nikolskoye',
#  'srednekolymsk',
#  'kuala terengganu',
#  'derzhavinsk',
#  'villanueva',
#  'lavrentiya',
#  'vaitupu',
#  'wattegama',
#  'tres arroyos',
#  'punta arenas',
#  'beitbridge',
#  'amuntai',
#  'paita',
#  'salalah',
#  'ternate',
#  'rawson',
#  'barinas',
#  'bom jesus',
#  'buchanan',
#  'arraial do cabo',
#  'ribeira grande',
#  'khatanga',
#  'broome',
#  'kavieng',
#  'sentyabrskiy',
#  'nishihara',
#  'cayenne',
#  'dedza',
#  'vanimo',
#  'saleaula',
#  'aksarka',
#  'turayf',
#  'locri',
#  'solnechnyy',
#  'labuhan',
#  'puerto ayora',
#  'dikson',
#  'kipini',
#  'bolungarvik',
#  'canton',
#  'aklavik',
#  'puerto quijarro',
#  'krasnoselkup',
#  'raudeberg',
#  'tayoltita',
#  'xichang',
#  'bambous virieux',
#  'itarema',
#  'yellowknife',
#  'kamenskoye',
#  'vangaindrano',
#  'belushya guba',
#  'hobart',
#  'nuuk',
#  'deder',
#  'riviere-au-renard',
#  'vardo',
#  'victoria',
#  'tuatapere',
#  'sola',
#  'port elizabeth',
#  'upernavik',
#  'kuusamo',
#  'samarai',
#  'louisbourg',
#  'kavaratti',
#  'kyle of lochalsh',
#  'jamestown',
#  'bredasdorp',
#  'bathsheba',
#  'amderma',
#  'praia da vitoria',
#  'nanortalik',
#  'sinkat',
#  'ilo',
#  'campbell river',
#  'berlevag',
#  'tygda',
#  'longyearbyen',
#  'mount gambier',
#  'saint george',
#  'turan',
#  'buqayq',
#  'nizhneyansk',
#  'yumen',
#  'muzaffarabad',
#  'chokurdakh',
#  'kabare',
#  'ulkan',
#  'balykshi',
#  'margate',
#  'ponta do sol',
#  'kuche',
#  'qujing',
#  'mandalgovi',
#  'eyrarbakki',
#  'sampit',
#  'gazli',
#  'avera',
#  'barentsburg',
#  'gamba',
#  'floro',
#  'dingle',
#  'labytnangi',
#  'kuah',
#  'beringovskiy',
#  'norrtalje',
#  'juneau',
#  'sitka',
#  'okha',
#  'lata',
#  'meulaboh',
#  'matadi',
#  'grand gaube',
#  'ilulissat',
#  'alugan',
#  'laguna',
#  'havoysund',
#  'pokoynoye',
#  'port-gentil',
#  'mahon',
#  'sobolevo',
#  'gandajika',
#  'deputatskiy',
#  'bethel',
#  'sorland',
#  'grand river south east',
#  'williams lake',
#  'karlstad',
#  'brigantine',
#  'amapa',
#  'tailai',
#  'pangnirtung',
#  'dingzhou',
#  'upata',
#  'lompoc',
#  'los llanos de aridane',
#  'santa cruz',
#  'santa catarina de tepehuanes',
#  'pyapon',
#  'saint-pierre',
#  'ghogha',
#  'viedma',
#  'mastic beach',
#  'yaan',
#  'kazerun',
#  'provost',
#  'chemal',
#  'touros',
#  'dwarka',
#  'samalaeulu',
#  'mnogovershinnyy',
#  'zyryanka',
#  'pisco',
#  'byron bay',
#  'lodingen',
#  'sisimiut',
#  'bambanglipuro',
#  'waterloo',
#  'mehamn',
#  'nsanje',
#  'tilichiki',
#  'puerto leguizamo',
#  'auki',
#  'yoichi',
#  'palmer',
#  'whitehorse',
#  'chagda',
#  'walvis bay',
#  'saskylakh',
#  'umzimvubu',
#  'chikoy',
#  'airai',
#  'polovinnoye',
#  'hirara',
#  'korla',
#  'pochutla',
#  'ojitlan',
#  'nisia floresta',
#  'rawannawi',
#  'portland',
#  'teopantlan',
#  'sayyan',
#  'liniere',
#  'san patricio',
#  'zaranj',
#  'lahij',
#  'tastur',
#  'okhotsk',
#  'noumea',
#  'iqaluit',
#  'lolua',
#  'kawalu',
#  'camargo',
#  'sabang',
#  'sinnamary',
#  'cranbrook',
#  'kangaatsiaq',
#  'montlucon',
#  'kayes',
#  'doctor pedro p. pena',
#  'angoche',
#  'constantine',
#  'marcona',
#  'geraldton',
#  'suzu',
#  'acapulco',
#  'seddon',
#  'sechura',
#  'yulara',
#  'durant',
#  'bilibino',
#  'ankpa',
#  'kalabagh',
#  'kavaje',
#  'karasjok',
#  'fortuna',
#  'kupang',
#  'witu',
#  'valea nucarilor',
#  'warqla',
#  'cap malheureux',
#  'naftah',
#  'pokhara',
#  'maltahohe',
#  'tabou',
#  'lasa',
#  'pirapozinho',
#  'batagay',
#  'fomboni',
#  'vao',
#  'hornepayne',
#  'qingdao',
#  'cabo san lucas',
#  'vila franca do campo',
#  'patti',
#  'nogliki',
#  'narsaq',
#  'malanje',
#  'armacao dos buzios',
#  'flinders',
#  'kruisfontein',
#  'vaitape',
#  'atasu',
#  'sterling',
#  'nacala',
#  'provideniya',
#  'akhnur',
#  'galesong',
#  'maarianhamina',
#  'puerto escondido',
#  'katsina',
#  'ares',
#  'santa maria',
#  'asau',
#  'ulagan',
#  'thana',
#  'esperance',
#  'morgan city',
#  'the valley',
#  'saldanha',
#  'dunedin',
#  'kani',
#  'sakaiminato',
#  'bud',
#  'kaeo',
#  'skibbereen',
#  'kargopol',
#  'imeni poliny osipenko',
#  'malmo',
#  'abu kamal',
#  'prainha',
#  'baghdad',
#  'batagay-alyta',
#  'leningradskiy',
#  'praia',
#  'ola',
#  'carnarvon',
#  'paracatu',
#  'bengkulu',
#  'makat',
#  'pevek',
#  'shingu',
#  'port hardy',
#  'homer',
#  'tual',
#  'marang',
#  'samusu',
#  'coquimbo',
#  'crab hill',
#  'sistranda',
#  'luena',
#  'oriximina',
#  'formoso do araguaia',
#  'salou',
#  'bomet',
#  'elko',
#  'maniitsoq',
#  'lagoa',
#  'makakilo city',
#  'taoudenni',
#  'chara',
#  'nantucket',
#  'talaya',
#  'sioux lookout',
#  'svetlyy',
#  'borovskoy',
#  'los alamos',
#  'svetlogorsk',
#  'xuddur',
#  'batticaloa',
#  'hualmay',
#  'robertsport',
#  'stip',
#  'poum',
#  'deh rawud',
#  'van',
#  'abalak',
#  'yebaishou',
#  'vila velha',
#  'chumikan',
#  'nguruka',
#  'panalingaan',
#  'vuktyl',
#  'ayat',
#  'luanda',
#  'gurskoye',
#  'axim',
#  'ambovombe',
#  'mareeba',
#  'huangyan',
#  'barstow',
#  'lodwar',
#  'port lincoln',
#  'kabinda',
#  'constitucion',
#  'almaznyy',
#  'lorengau',
#  'chicama',
#  'vohibinany',
#  'burley',
#  'takoradi',
#  'banda aceh',
#  'vestmannaeyjar',
#  'roros',
#  'aksu',
#  'mackay',
#  'taltal',
#  'oktyabrskiy',
#  'honiara',
#  'shimanovsk',
#  'gubkinskiy',
#  'kourou',
#  'plettenberg bay',
#  'malpe',
#  'faanui',
#  'marawi',
#  'olafsvik',
#  'santa vitoria do palmar',
#  'stykkisholmur',
#  'leek',
#  'itaituba',
#  'rio branco',
#  'hobyo',
#  'muswellbrook',
#  'zhaoyuan',
#  'nabire',
#  'potiskum',
#  'haines junction',
#  'canalete',
#  'gwembe',
#  'hamilton',
#  'saint-augustin',
#  'alyangula',
#  'birin',
#  'zhangye',
#  'vestmanna',
#  'chakia',
#  'pauini',
#  'sao jose da coroa grande',
#  'garowe',
#  'bandarbeyla',
#  'lazaro cardenas',
#  'khvorostyanka',
#  'cravo norte',
#  'oistins',
#  'nyurba',
#  'astana',
#  'sedan',
#  'kamaishi',
#  'karaton',
#  'zhicheng',
#  'shubarshi',
#  'manokwari',
#  'sao joao da barra',
#  'saint-joseph',
#  'nandu',
#  'beisfjord',
#  'nhulunbuy',
#  'djenne',
#  'huai yot',
#  'bolshegrivskoye',
#  'klaksvik',
#  'coihaique',
#  'fevralsk',
#  'nouakchott',
#  'kabompo',
#  'tahe',
#  'fort abbas',
#  'zelenogorskiy',
#  'menongue',
#  'xinpu',
#  'voznesenye',
#  'soyo',
#  'guasdualito',
#  'mitchell',
#  'urdzhar',
#  'comodoro rivadavia',
#  'itaqui',
#  'thayetmyo',
#  'biak',
#  'ketchikan',
#  'primorsk',
#  'jian',
#  'fukue',
#  'kirakira',
#  'jaisalmer',
#  'kerema',
#  'yako',
#  'jalu',
#  'krasnovishersk',
#  'colares',
#  'bontang',
#  'mayo',
#  'kaspiysk',
#  'matagami',
#  'pincher creek',
#  'gizo',
#  'zhanaozen',
#  'copiapo',
#  'riyadh',
#  'san luis',
#  'mys shmidta',
#  'diphu',
#  'mitsamiouli',
#  'tumannyy',
#  'auburn',
#  'panjab',
#  'salym',
#  'grindavik',
#  'katsuura',
#  'awjilah',
#  'sabha',
#  'lahaina',
#  'tezu',
#  'boysun',
#  'ponta delgada',
#  'husavik',
#  'gympie',
#  'pandan',
#  'gondanglegi',
#  'sao filipe',
#  'zhanakorgan',
#  'colombo',
#  'qaqortoq',
#  'nehe',
#  'kozan',
#  'bubaque',
#  'krivosheino',
#  'goya',
#  'khonuu',
#  'maua',
#  'kitahiroshima',
#  'klyuchi',
#  'kutum',
#  'hovsan',
#  'kamyaran',
#  'marsa matruh',
#  'the pas',
#  'tsabong',
#  'keti bandar',
#  'tiznit',
#  'aguimes',
#  'mattru',
#  'wuda',
#  'nouadhibou',
#  'puerto ayacucho',
#  'buraydah',
#  'hofn',
#  'araouane',
#  'grindu',
#  'baykit',
#  'seoul',
#  'aktash',
#  'panaba',
#  'clyde river',
#  'rafaela',
#  'tambacounda',
#  'bonthe',
#  'urucara',
#  'teya',
#  'atambua',
#  'verkhnyaya toyma',
#  'ramanuj ganj',
#  'noshiro',
#  'duz',
#  'mizpe ramon',
#  'simao',
#  'agadir']

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# Sort Data
city_final = []
cloud = []
lat = []
lng = []
temp_max = []
country = []
date = []
humid = []
wind = []
counter = 0


#API Measures for 60 request per minute max issues
time.sleep(61)

for city in cities:
    try:
        response = requests.get(query_url + city).json()
    except:
        time.sleep(61)
    if response['cod'] != "404":
        counter += 1
        print(f"Processing Record {counter} of Set 1| {city}")
        city_final.append(city.title())
        cloud.append(response['clouds']['all'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp_max.append(response['main']['temp_max'])
        country.append(response["sys"]["country"])
        date.append(response['dt'])
        humid.append(response['main']["humidity"])
        wind.append(response['wind']["speed"])
        time.sleep(1)
    else:
        print("City not found. Skipping...")
        time.sleep(1) 


weather_dict = {
    "City": city_final,
    "Country": country,
    "Date": date,
    "Lng": lng,
    "Lat": lat,
    "Max Temp": temp_max,
    "Cloudiness": cloud, 
    "Humidity": humid,
    "Wind Speed": wind
}
# Out:
# Processing Record 1 of Set 1| vizinga
# Processing Record 2 of Set 1| mataura
# Processing Record 3 of Set 1| cherskiy
# Processing Record 4 of Set 1| barrow
# Processing Record 5 of Set 1| atuona
# Processing Record 6 of Set 1| lebu
# Processing Record 7 of Set 1| georgetown
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of Set 1| henties bay
# Processing Record 9 of Set 1| luderitz
# Processing Record 10 of Set 1| hay river
# Processing Record 11 of Set 1| kodiak
# Processing Record 12 of Set 1| ushuaia
# Processing Record 13 of Set 1| mahebourg
# Processing Record 14 of Set 1| tiksi
# Processing Record 15 of Set 1| saint-philippe
# Processing Record 16 of Set 1| winkler
# Processing Record 17 of Set 1| severo-kurilsk
# Processing Record 18 of Set 1| kinablangan
# Processing Record 19 of Set 1| kahului
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 20 of Set 1| albany
# Processing Record 21 of Set 1| torbay
# Processing Record 22 of Set 1| karratha
# Processing Record 23 of Set 1| kaitangata
# Processing Record 24 of Set 1| kapaa
# Processing Record 25 of Set 1| thompson
# Processing Record 26 of Set 1| saint-paul
# Processing Record 27 of Set 1| fairbanks
# Processing Record 28 of Set 1| evensk
# Processing Record 29 of Set 1| vaini
# City not found. Skipping...
# Processing Record 30 of Set 1| chuy
# Processing Record 31 of Set 1| castro
# Processing Record 32 of Set 1| mar del plata
# Processing Record 33 of Set 1| hermanus
# Processing Record 34 of Set 1| cockburn town
# Processing Record 35 of Set 1| zheleznodorozhnyy
# Processing Record 36 of Set 1| harper
# Processing Record 37 of Set 1| puerto carreno
# Processing Record 38 of Set 1| port alfred
# Processing Record 39 of Set 1| waipawa
# Processing Record 40 of Set 1| busselton
# Processing Record 41 of Set 1| namatanai
# Processing Record 42 of Set 1| san cristobal
# Processing Record 43 of Set 1| butaritari
# Processing Record 44 of Set 1| cidreira
# Processing Record 45 of Set 1| beloha
# Processing Record 46 of Set 1| zaragoza
# Processing Record 47 of Set 1| am timan
# Processing Record 48 of Set 1| guerrero negro
# Processing Record 49 of Set 1| ostrovnoy
# Processing Record 50 of Set 1| maple creek
# Processing Record 51 of Set 1| norman wells
# Processing Record 52 of Set 1| new norfolk
# Processing Record 53 of Set 1| artyom
# Processing Record 54 of Set 1| santo anastacio
# Processing Record 55 of Set 1| souillac
# Processing Record 56 of Set 1| dinghai
# Processing Record 57 of Set 1| lingao
# Processing Record 58 of Set 1| hami
# City not found. Skipping...
# Processing Record 59 of Set 1| hithadhoo
# City not found. Skipping...
# Processing Record 60 of Set 1| santiago
# Processing Record 61 of Set 1| numan
# Processing Record 62 of Set 1| alice springs
# Processing Record 63 of Set 1| pouembout
# Processing Record 64 of Set 1| piacabucu
# Processing Record 65 of Set 1| schweinfurt
# City not found. Skipping...
# Processing Record 66 of Set 1| qaanaaq
# Processing Record 67 of Set 1| sept-iles
# Processing Record 68 of Set 1| ovsyanka
# City not found. Skipping...
# Processing Record 69 of Set 1| hilo
# Processing Record 70 of Set 1| tura
# Processing Record 71 of Set 1| east london
# Processing Record 72 of Set 1| northam
# Processing Record 73 of Set 1| tasiilaq
# Processing Record 74 of Set 1| cape town
# Processing Record 75 of Set 1| faya
# Processing Record 76 of Set 1| bluff
# Processing Record 77 of Set 1| fare
# Processing Record 78 of Set 1| fort nelson
# Processing Record 79 of Set 1| tuktoyaktuk
# Processing Record 80 of Set 1| rikitea
# Processing Record 81 of Set 1| fez
# Processing Record 82 of Set 1| kushiro
# Processing Record 83 of Set 1| hasaki
# Processing Record 84 of Set 1| avarua
# Processing Record 85 of Set 1| ancud
# Processing Record 86 of Set 1| belyy yar
# Processing Record 87 of Set 1| namibe
# Processing Record 88 of Set 1| russell
# Processing Record 89 of Set 1| aksay
# Processing Record 90 of Set 1| alta floresta
# Processing Record 91 of Set 1| tommot
# Processing Record 92 of Set 1| nikolskoye
# Processing Record 93 of Set 1| srednekolymsk
# Processing Record 94 of Set 1| kuala terengganu
# Processing Record 95 of Set 1| derzhavinsk
# Processing Record 96 of Set 1| villanueva
# Processing Record 97 of Set 1| lavrentiya
# City not found. Skipping...
# Processing Record 98 of Set 1| wattegama
# Processing Record 99 of Set 1| tres arroyos
# Processing Record 100 of Set 1| punta arenas
# Processing Record 101 of Set 1| beitbridge
# Processing Record 102 of Set 1| amuntai
# Processing Record 103 of Set 1| paita
# Processing Record 104 of Set 1| salalah
# Processing Record 105 of Set 1| ternate
# Processing Record 106 of Set 1| rawson
# Processing Record 107 of Set 1| barinas
# Processing Record 108 of Set 1| bom jesus
# Processing Record 109 of Set 1| buchanan
# Processing Record 110 of Set 1| arraial do cabo
# Processing Record 111 of Set 1| ribeira grande
# Processing Record 112 of Set 1| khatanga
# Processing Record 113 of Set 1| broome
# Processing Record 114 of Set 1| kavieng
# City not found. Skipping...
# Processing Record 115 of Set 1| nishihara
# Processing Record 116 of Set 1| cayenne
# Processing Record 117 of Set 1| dedza
# Processing Record 118 of Set 1| vanimo
# City not found. Skipping...
# Processing Record 119 of Set 1| aksarka
# Processing Record 120 of Set 1| turayf
# Processing Record 121 of Set 1| locri
# Processing Record 122 of Set 1| solnechnyy
# Processing Record 123 of Set 1| labuhan
# Processing Record 124 of Set 1| puerto ayora
# Processing Record 125 of Set 1| dikson
# Processing Record 126 of Set 1| kipini
# City not found. Skipping...
# Processing Record 127 of Set 1| canton
# Processing Record 128 of Set 1| aklavik
# Processing Record 129 of Set 1| puerto quijarro
# City not found. Skipping...
# Processing Record 130 of Set 1| raudeberg
# Processing Record 131 of Set 1| tayoltita
# Processing Record 132 of Set 1| xichang
# Processing Record 133 of Set 1| bambous virieux
# Processing Record 134 of Set 1| itarema
# Processing Record 135 of Set 1| yellowknife
# City not found. Skipping...
# Processing Record 136 of Set 1| vangaindrano
# City not found. Skipping...
# Processing Record 137 of Set 1| hobart
# Processing Record 138 of Set 1| nuuk
# Processing Record 139 of Set 1| deder
# Processing Record 140 of Set 1| riviere-au-renard
# Processing Record 141 of Set 1| vardo
# Processing Record 142 of Set 1| victoria
# Processing Record 143 of Set 1| tuatapere
# Processing Record 144 of Set 1| sola
# Processing Record 145 of Set 1| port elizabeth
# Processing Record 146 of Set 1| upernavik
# Processing Record 147 of Set 1| kuusamo
# Processing Record 148 of Set 1| samarai
# City not found. Skipping...
# Processing Record 149 of Set 1| kavaratti
# City not found. Skipping...
# Processing Record 150 of Set 1| jamestown
# Processing Record 151 of Set 1| bredasdorp
# Processing Record 152 of Set 1| bathsheba
# City not found. Skipping...
# Processing Record 153 of Set 1| praia da vitoria
# Processing Record 154 of Set 1| nanortalik

# %%
#Create DataFrame
data = pd.DataFrame(weather_dict)
data.head()

# %%
#Check and Save Data as CSV
data.count()
data.to_csv("Places Data.csv", index=False, header=True)

# %%
#Plotting the Data
#Latitude vs. Temperature Plot
plt.scatter(data["Lat"], data["Max Temp"],alpha=0.3)
plt.title("Latitude vs. Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)
# Save the Figure
plt.savefig("Latitude vs. Temperature Plot.png")
# Show Figure
plt.show()

# %%
#Plotting the Data
#Latitude vs. Humidity Plot
plt.scatter(data["Lat"], data["Humidity"],alpha=0.3)
plt.title("Latitude vs. Humidity Plot")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid(True)
# Save the Figure
plt.savefig("Latitude vs. Humidity Plot.png")
# Show Figure
plt.show()

# %%
#Plotting the Data
#Latitude vs. Cloudiness Plot
plt.scatter(data["Lat"], data["Cloudiness"],alpha=0.3)
plt.title("Latitude vs. Cloudiness Plot")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid(True)
# Save the Figure
plt.savefig("Latitude vs. Cloudiness Plot.png")
# Show Figure
plt.show()

# %%
#Plotting the Data
#Latitude vs. Wind Speed Plot
plt.scatter(data["Lat"], data["Wind Speed"],alpha=0.3)
plt.title("Latitude vs. Wind Speed Plot")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (KT)")
plt.grid(True)
# Save the Figure
plt.savefig("Latitude vs. Wind Speed Plot.png")
# Show Figure
plt.show()
